# %%
import openai

# %%
from openai import OpenAI

# %%
client = OpenAI()

# %%
import os

# %%
response = client.chat.completions.create(
    model = 'gpt-4o',
    messages=[{"role": "user", "content": "is it too laste to join the course?"}]
)

# %%
response.choices[0].message.content
# Out:
# "I'm sorry, I would need more context to provide a specific answer. Could you specify which course you are referring to and any relevant deadlines or start dates associated with it?"
